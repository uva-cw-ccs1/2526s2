# %% [markdown]
# # Tutorial 2: Coding Exercise
#
# ## Movie Database Practice
#
# Work through the following tasks using the movie data provided below.

# %% [markdown]
# ---
#
# ## Data Setup
#
# Run these cells to set up the movie data:

# %%
movies = ["Gladiator", "The Matrix", "The Lord of the Rings", "Citizen Kane", "Avatar 2", "Inside Out 2", "Jaws"]

# %%
year = [2000, 1999, 2001, 1941, 2022, 2024, 1975]

# %%
score = [8.5, 8.7, 8.9, 8.2, 7.5, 7.5, 8.1]

# %%
is_watched = [True, True, True, False, True, False, False]

# %% [markdown]
# ---
#
# ## Examples
#
# Here are some examples to help you get started:

# %%
# Example 1: Loop through all movies
for movie in movies:
    print(movie)
# Out:
# Gladiator
# The Matrix
# The Lord of the Rings
# Citizen Kane
# Avatar 2
# Inside Out 2
# Jaws

# %%
# Example 2: Find the index of "Jaws"
jaws_index = movies.index("Jaws")

# %%
# Example 3: Use the index to get the score
print(score[jaws_index])
# Out:
# 8.1

# %% [markdown]
# ---
#
# ## Tasks
#
# Complete the following tasks in the code cells provided:

# %% [markdown]
# ### Task 1: Update Watched Status
#
# Update the `is_watched` variable to reflect your experience, but don't change what's written in the fourth position (index 3).

# %%
# Your code here:

# %% [markdown]
# ### Task 2: Add More Movies
#
# Add 2 more movies to the database with their years, scores, and watched status.
#
# **Hint:** Use `.append()` to add items to each list.

# %%
# Your code here:

# %% [markdown]
# ### Task 3: Count Watched Movies
#
# Write code to count how many movies you've watched and print the result.

# %%
# Your code here:

# %% [markdown]
# ### Task 4: Find Old Movies
#
# Print the names of all movies that premiered before the year 2000.
#
# **Hint:** Use `<` to check if a number is smaller than another.

# %%
# Your code here:

# %% [markdown]
# ### Task 5: Adjust Movie Scores
#
# Movie critics have decided to decrease all movie scores by 1! Create a new list called `new_scores` and fill it with the decreased scores.

# %%
# Your code here:

# %% [markdown]
# ### Task 6: Search for "Rings"
#
# Someone is talking about a movie with "Rings" in the title. Write code to check every movie and find the one with "Rings" in it, then print its full name.
#
# **Hint:** Use the `in` keyword to check if a substring exists in a string.

# %%
# Your code here:

# %% [markdown]
# ### Task 7: Spell Out Movie Name
#
# Someone wants to know how to spell the second movie's name, letter by letter. Write code to print each letter on a separate line.

# %%
# Your code here:

# %% [markdown]
# ### Task 8: Categorize Movies by Score
#
# Create two new lists:
# - `must_be_watched`: movies with scores ≥ 8.3 (from the original `score` list)
# - `optional_to_watch`: all other movies
#
# Print both lists when done.

# %%
# Your code here:
