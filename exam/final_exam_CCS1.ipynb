# %% [markdown]
# # Final Exam
#
# **Student name:**
#
# **Student number:**
#
# This is your final exam for CCS1. In this exam you will demonstrate the Python skills you have developed throughout the course.
#
# * You are allowed to use your study materials from the course (e.g., slides, notebooks, solutions to weekly practice) during the exam.
# * When you are finished, double check that you have answered all questions and the notebook is saved before submitting.
# * Carefully read the instructions for each question! Not only the notes in the code cell but also the instructions in the markdown cells!
#
# **General instructions:**
#
# * This exam consists of a Jupyter Notebook with **8 questions** worth a total of **100 points**.
# * Fill in your name and student number in the space above.
# * Write your answers in the designated cells (code or markdown, as instructed). You may add extra cells if needed.
# * For the code you write, try to include very brief comments explaining what it does (e.g., using `#`).
# * **Do not perform unnecessary steps.** Keep your answers focused.
#
# **Submission instructions (for FINAL EXAM):**
#
# * When finished (and all code executed), export the notebook: File → Download As → HTML.
# * Rename the file (if you can): `LastName_FirstName_StudentID_CCS1.html`
# * Upload the HTML file to Canvas.
# * If you cannot generate an HTML file, upload the notebook (`.ipynb`) directly and inform your teacher.
#
# **Good luck!**

# %% [markdown]
# ---
# ## The Dataset
#
# The data cell below contains information about a fictional music streaming platform. Run it before starting the exam - the lists are used throughout Questions 1–5.
#
# Each list contains one value per song:
#
# * `song_titles` - title of the song
# * `artists` - name of the performing artist
# * `genres` - genre of the song
# * `plays` - total number of plays **in millions**
# * `is_featured` - whether the song is currently featured on the home page

# %%
import pandas as pd  # import pandas - needed for Questions 6, 7, and 8

# Music streaming platform data
song_titles = [
    "Blinding Lights", "Levitating", "Stay", "Peaches", "Good 4 U",
    "Montero", "Leave The Door Open", "Drivers License", "Butter", "Easy On Me"
]

artists = [
    "The Weeknd", "Dua Lipa", "Kid Laroi", "Justin Bieber", "Olivia Rodrigo",
    "Lil Nas X", "Silk Sonic", "Olivia Rodrigo", "BTS", "Adele"
]

genres = [
    "pop", "pop", "pop", "pop", "pop",
    "hip-hop", "r&b", "pop", "pop", "pop"
]

plays = [
    1430, 980, 1150, 870, 760,
    920, 590, 1380, 1050, 690
]  # total plays in millions

is_featured = [
    False, False, True, False, False,
    False, False, False, True, False
]

# %% [markdown]
# ---
# ## Plan your code (5 points)
#
# Before writing any code, take a few minutes to plan your answers.
#
# For **Questions 3, 4, 5, 7, and 8**, briefly describe the steps you will take to complete each task. Write in plain English - bullet points or short sentences are fine.
#
# *Note: there are many correct answers here. We are looking for logical and clear reasoning.*

# %% [markdown]
# **Your plan:**
#
# **Question 3:**
#
# **Question 4:**
#
# **Question 5:**
#
# **Question 7:**
#
# **Question 8:**

# %% [markdown]
# ---
# ## Question 1: Variables and data types (10 points)
#
# The code cell below contains several variables.
#
# * **1a.** Run the cell and observe the output.
# * **1b.** For each of the four variables (`platform_name`, `num_songs`, `avg_rating`, `is_active`), print its data type using `type()`.
# * **1c.** Compute the **total plays** by adding `plays_song_a` and `plays_song_b`. Store the result in a variable called `total_plays` and print it.
# * **1d.** In the markdown cell below, state the data type of each variable.
#
# *Do not forget to document your code briefly.*

# %%
# These variables are given - do not change them. These variables are not related to the music streaming platform data above.
platform_name = "StreamFly"  # name of the platform
num_songs = 10               # number of songs in the dataset
avg_rating = 8.4             # average song rating
is_active = True             # whether the platform is currently active
plays_song_a = 1430          # plays for song A (in millions)
plays_song_b = 980           # plays for song B (in millions)

# Task 1b: Print the data type of each variable using type()
# Your code here:


# Task 1c: Compute total_plays and print it
# Your code here:

# %% [markdown]
# **Your answer for 1d (data types):**
#
# * `platform_name`:
# * `num_songs`:
# * `avg_rating`:
# * `is_active`:

# %% [markdown]
# ---
# ## Question 2: Working with lists (10 points)
#
# Use the lists `song_titles`, `artists`, `genres`, `plays`, and `is_featured` defined in the data cell at the top of the notebook.
#
# * **2a.** Print the **first** song title and the **last** artist name using indexing.
# * **2b.** Print a slice of `song_titles` containing only the **first three** songs.
# * **2c.** Print the total number of songs (`len()`), the highest play count (`max()`), and the lowest play count (`min()`).
# * **2d.** A new song has just been added to the platform. Append the following values to the appropriate lists:
#   * title: `"Stay With Me"`, artist: `"Ed Sheeran"`, genre: `"pop"`, plays: `810`, is_featured: `False`
#
#   Then print the **updated length** of `song_titles` to confirm the addition.
#
# *Do not forget to document your code briefly.*

# %%
# Task 2a: Print the first song title and the last artist name
# Your code here:


# Task 2b: Print a slice with the first three song titles
# Your code here:


# Task 2c: Print number of songs, max plays, min plays
# Your code here:


# Task 2d: Append the new song to each list, then print the updated length
# Your code here:

# %% [markdown]
# ---
# ## Question 3: Loops and conditionals (15 points)
#
# Fill in the blanks (`_____`) in the code cell below so that it performs the three tasks correctly. Make sure all code runs and produces visible output.
#
# * **3a.** Count how many songs have more than **900 million** plays.
# * **3b.** Build a list called `popular_songs` containing the **titles** of all songs with more than **900 million** plays.
# * **3c.** Print the title and genre of each song, but **only** for songs in the `"pop"` genre.
#
# For each line of code, provide a brief comment explaining what it does.
#
# **Note:** Use the lists as they are at this point in the notebook (i.e., including any song added in Question 2).

# %%
# Task 3a: Count songs with more than 900 million plays
count = _____                          # initialise counter to zero
for i in range(len(song_titles)):      # loop over each index
    if plays[i] > _____:              # check if plays exceed the threshold
        count += _____                # increment the counter
print("Songs with more than 900M plays:", count)

# Task 3b: Collect titles of songs with more than 900 million plays
popular_songs = _____                  # start with an empty list
for i in range(len(song_titles)):
    if plays[i] > 900:
        popular_songs._____(song_titles[i])   # add the title to the list
print("Popular song titles:", popular_songs)

# Task 3c: Print the title and genre for every pop song
for i in range(_____):
    if genres[i] == _____:            # check if the genre is pop
        print(song_titles[i], "-", genres[i])

# %% [markdown]
# ---
# ## Question 4: Dictionaries (15 points)
#
# * **4a.** Using the `song_info` dictionary below, access and print the song's **title** and **artist**.
# * **4b.** Add a new key `"label"` with the value `"Republic Records"` to `song_info`.
# * **4c.** Check whether the key `"producer"` exists in `song_info` and print `True` or `False`.
# * **4d.** Use a `for` loop with `.items()` to print every key-value pair in `song_info` in the format: `key: value`
# * **4e.** Using the `weekly_plays` dictionary, print the play count for `"Levitating"`.
#
# *Do not forget to document your code briefly.*

# %%
# Song information dictionary - given, do not change
song_info = {
    "title": "Blinding Lights",
    "artist": "The Weeknd",
    "genre": "pop",
    "year": 2019,
    "plays": 1430
}

# Task 4a: Print the title and artist
# Your code here:


# Task 4b: Add the key "label" with value "Republic Records"
# Your code here:


# Task 4c: Check whether "producer" is a key in song_info and print the result
# Your code here:


# Task 4d: Loop through song_info and print each key-value pair in the requested format
# Your code here:


# Weekly play counts (in thousands) - given, do not change
weekly_plays = {
    "Blinding Lights": 28,
    "Levitating": 19,
    "Drivers License": 31,
    "Good 4 U": 15,
    "Butter": 22
}

# Task 4e: Print the weekly play count for "Levitating"
# Your code here:

# %% [markdown]
# ---
# ## Question 5: Functions (15 points)
#
# * **5a.** Write a function called `classify_song` that takes one argument `play_count` (a number in millions).
#   It should return:
#   * `"hit"` if `play_count >= 1000`
#   * `"popular"` if `play_count >= 700`
#   * `"niche"` otherwise
#
#   Call your function with the values `1430`, `870`, and `590`, and print each result.
#
# * **5b.** Write a function called `describe_song` that takes two arguments:
#   * `title` - the song's title (required)
#   * `genre` - the song's genre (optional, with a **default value** of `"unknown"`)
#
#   The function should **print** (not return) a sentence in this format:
#   `"[title] is a [genre] song."`
#
#   Call it **twice**:
#   1. With both arguments: `title="Blinding Lights"`, `genre="pop"`
#   2. With only the title: `title="Mystery Track"` (the default genre should be used)
#
# *Do not forget to document your code briefly.*

# %%
# Task 5a: Define classify_song and call it three times
# Your code here:



# Task 5b: Define describe_song (with a default parameter) and call it twice
# Your code here:

# %% [markdown]
# ---
# ## The Pandas Dataset
#
# The data cell below contains a fictional dataset of music albums. Run it before starting Questions 6–8.

# %%
# Album dataset for the Pandas section
album_data = {
    "title":      ["Midnights", "Certified Lover Boy", "Planet Her", "Future Nostalgia",
                   "After Hours", "Sour", "Justice", "30",
                   "Happier Than Ever", "Un Verano Sin Ti"],
    "artist":     ["Taylor Swift", "Drake", "Doja Cat", "Dua Lipa",
                   "The Weeknd", "Olivia Rodrigo", "Justin Bieber", "Adele",
                   "Billie Eilish", "Bad Bunny"],
    "genre":      ["pop", "hip-hop", "pop", "pop",
                   "r&b", "pop", "pop", "pop",
                   "pop", "latin"],
    "year":       [2022, 2021, 2021, 2020,
                   2020, 2021, 2021, 2021,
                   2021, 2022],
    "streams_m":  [1820, 2150, 980, 1450,
                   1700, 1100, 890, 1230,
                   760, 2400],  # total streams in millions
    "tracks":     [13, 21, 15, 11,
                   14, 11, 16, 12,
                   16, 23]
}

# %% [markdown]
# ---
# ## Question 6: Creating and exploring the DataFrame (10 points)
#
# * **6a.** Convert the `album_data` dictionary into a Pandas DataFrame called `albums_df`.
# * **6b.** Inspect the DataFrame:
#   * Display the first 5 rows.
#   * Print the shape (number of rows and columns).
#   * Print the data types of each column using `.info()`.
# * **6c.** In the markdown cell below, answer: How many albums are in the dataset? What data types do the columns have?
#
# *Do not forget to document your code briefly.*

# %%
# Task 6a: Convert album_data to a Pandas DataFrame
# Your code here:

# %%
# Task 6b: Inspect the DataFrame (first 5 rows)
# Your code here:

# %%
# Task 6b: Inspect the DataFrame (shape)
# Your code here:

# %%
# Task 6b: Inspect the DataFrame (info)
# Your code here:

# %% [markdown]
# **Your answer for 6c:**
#
# * Number of albums in the dataset:
# * Data types of the columns:

# %% [markdown]
# ---
# ## Question 7: Filtering and sorting the DataFrame (10 points)
#
# Fill in the blanks (`_____`) in the code below so that it correctly filters and sorts `albums_df`. Make sure all code runs and produces visible output.
#
# For each line of code, provide a brief comment explaining what it does.

# %%
# Task 7a: Show only albums with 1000 million streams or more
high_streams = albums_df[albums_df[_____] >= _____]    # filter rows where streams meet the condition
print(high_streams)

# Task 7b: Show only pop albums
pop_albums = albums_df[albums_df[_____] == _____]      # filter rows where genre is pop
print(pop_albums)

# Task 7c: Show albums released in 2021 or later AND with fewer than 1000 million streams
recent_low = albums_df[(albums_df[_____] >= _____) & (albums_df[_____] < _____)]  # combine two conditions
print(recent_low)

# Task 7d: Sort albums_df by number of streams from highest to lowest and print the result
albums_sorted = albums_df.sort_values(_____, ascending=_____)   # sort by the streams column
print(albums_sorted)

# %% [markdown]
# ---
# ## Question 8: Analysing and transforming the data (10 points)
#
# Complete all four tasks in the code cell below.
#
# For each line of code, provide a brief comment explaining what it does.

# %%
# Task 8a: Calculate and print the average number of streams across all albums


# Task 8b: Calculate and print the total number of streams (in millions) across all albums


# Task 8c: Add a new boolean column called "blockbuster" to albums_df
#          It should be True if streams_m >= 1500, and False otherwise


# Task 8d: Write a function called categorise_album that takes a streams_m value and returns:
#          "low"    if streams_m < 1000
#          "medium" if 1000 <= streams_m < 1700
#          "high"   if streams_m >= 1700
#          Then apply it to the "streams_m" column to create a new column called "streams_category".
#          Finally, print albums_df[["title", "streams_m", "blockbuster", "streams_category"]]
#          to check your work.
