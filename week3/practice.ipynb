# %% [markdown]
# # 🐍 Week 3 Coding Practice
#
# **Welcome to Week 3!** This notebook reviews past content and introduces dictionaries.
#
# **Topics covered:**
# - Review: Data types, variables, lists, loops, conditionals
# - New: Dictionaries (key-value pairs)
#
# **Instructions:**
# - Complete each exercise in order
# - Test your code by running each cell
# - Don't skip the review - it builds foundation for dictionaries!
#
# ---

# %% [markdown]
# ## Part 1: Review of Weeks 1-2 📚
#
# Let's reinforce what we've learned!

# %% [markdown]
# ### Exercise 1.1: Working with Data Types
# Create a variable for each data type with these values:
# - `temperature`: 72.5 (float)
# - `students_count`: 30 (integer)
# - `university_name`: "University of Amsterdam" (string)
# - `is_online`: False (boolean)
#
# Then use `type()` to verify the type of `temperature`.

# %%
# Your code here:

# %% [markdown]
# ### Exercise 1.2: Variable Operations
# Create a variable `views` with value 1000. Then:
# 1. Add 250 views using `+=`
# 2. Triple the views using `*=`
# 3. Print the final number of views

# %%
# Your code here:

# %% [markdown]
# ### Exercise 1.3: String Manipulation
# Given two variables `first = "Data"` and `second = "Science"`:
# 1. Combine them with a space to create `field`
# 2. Print `field` in uppercase
# 3. Print the length of `field`

# %%
# Your code here:

# %% [markdown]
# ### Exercise 1.4: List Basics
# Create a list `ratings` containing: 4.5, 3.8, 4.9, 4.2, 3.5
#
# Then:
# 1. Print the first rating
# 2. Print the last rating (using negative index)
# 3. Add a new rating 4.7 to the end
# 4. Change the second rating to 4.0
# 5. Print the updated list

# %%
# Your code here:

# %% [markdown]
# ### Exercise 1.5: List Functions
# Given the list: `sales = [120, 150, 180, 95, 200, 165, 140]`
#
# Calculate and print:
# 1. Total sales (sum)
# 2. Average sales
# 3. Highest sale
# 4. Lowest sale
# 5. Number of sales recorded

# %%
# Your code here:

# %% [markdown]
# ### Exercise 1.6: For Loops - Basic Printing
# Given: `cities = ['Amsterdam', 'Berlin', 'Paris', 'London', 'Rome']`
#
# Use a for loop to print each city with its position:
# ```
# 1. Amsterdam
# 2. Berlin
# 3. Paris
# ...
# ```
#
# Hint: You can use `enumerate()` or track a counter yourself.

# %%
# Your code here:

# %% [markdown]
# ### Exercise 1.7: For Loops - Building a New List
# Given: `numbers = [3, 7, 12, 5, 18, 9, 21]`
#
# Use a for loop to create a new list `even_numbers` containing only the even numbers.
#
# Hint: Use `%` (modulo) to check if a number is even: `number % 2 == 0`

# %%
# Your code here:

# %% [markdown]
# ### Exercise 1.8: Conditionals - Grading System
# Create a variable `score = 78`. Write if-elif-else statements to print the grade:
# - "A" if score >= 90
# - "B" if score >= 80
# - "C" if score >= 70
# - "D" if score >= 60
# - "F" if score < 60

# %%
# Your code here:

# %% [markdown]
# ### Exercise 1.9: Loops + Conditionals
# Given: `prices = [45, 120, 30, 85, 150, 20, 95]`
#
# Use a loop with conditionals to:
# 1. Count how many prices are "expensive" (>= 100)
# 2. Count how many prices are "moderate" (50-99)
# 3. Count how many prices are "cheap" (< 50)
# 4. Print all three counts

# %%
# Your code here:

# %% [markdown]
# ### Exercise 1.10: String Operations in Loops
# Given: `tags = ['#python', '#DataScience', '#AI', '#MachineLearning', '#coding']`
#
# Use a loop to:
# 1. Print only tags that contain "data" or "Data" (case-insensitive)
# 2. Count how many tags are longer than 8 characters
#
# Hint: Use `.lower()` to make comparisons case-insensitive.

# %%
# Your code here:

# %% [markdown]
# ---
#
# ## Part 2: Dictionaries - New Content! 📖
#
# Now let's learn about dictionaries - a powerful way to organize data!

# %% [markdown]
# ### Exercise 2.1: Create Your First Dictionary
# Create a dictionary called `profile` with these key-value pairs:
# - "username": "alex_2024"
# - "age": 21
# - "followers": 1500
# - "verified": True
#
# Print the entire dictionary.

# %%
# Your code here:

# %% [markdown]
# ### Exercise 2.2: Accessing Dictionary Values
# Using the `profile` dictionary from above:
# 1. Print the username
# 2. Print the number of followers
# 3. Check if "verified" is a key in the dictionary (should print True)

# %%
# Your code here:

# %% [markdown]
# ### Exercise 2.3: Modifying Dictionaries
# Create this dictionary:
# ```python
# car = {
#     "brand": "Toyota",
#     "model": "Camry",
#     "year": 2020
# }
# ```
#
# Then:
# 1. Change the year to 2022
# 2. Add a new key "color" with value "Silver"
# 3. Add a new key "price" with value 25000
# 4. Print the updated dictionary

# %%
# Your code here:

# %% [markdown]
# ### Exercise 2.4: Dictionary Methods
# Create this dictionary:
# ```python
# restaurant = {
#     "name": "Pasta Palace",
#     "cuisine": "Italian",
#     "rating": 4.5,
#     "price_range": "$$"
# }
# ```
#
# Then:
# 1. Print all the keys using `.keys()`
# 2. Print all the values using `.values()`
# 3. Check if "location" is a key (should print False)

# %%
# Your code here:

# %% [markdown]
# ### Exercise 2.5: Looping Through Dictionaries
# Create this dictionary:
# ```python
# inventory = {
#     "apples": 50,
#     "bananas": 75,
#     "oranges": 30,
#     "grapes": 60
# }
# ```
#
# Then:
# 1. Use a loop to print each fruit name
# 2. Use a loop to calculate the total quantity of all fruits
# 3. Use a loop to print items with quantity >= 50

# %%
# Your code here:

# %% [markdown]
# ### Exercise 2.6: Dictionary with Loops and Conditionals
# Create this dictionary:
# ```python
# exam_scores = {
#     "Emma": 92,
#     "Noah": 87,
#     "Olivia": 95,
#     "Liam": 78,
#     "Ava": 88
# }
# ```
#
# Use a loop to:
# 1. Print students who scored >= 90
# 2. Calculate the class average
# 3. Count how many students passed (>= 80)

# %%
# Your code here:

# %% [markdown]
# ### Exercise 2.7: Creating Dictionaries from Lists
# You have two parallel lists:
# ```python
# products = ["Laptop", "Mouse", "Keyboard", "Monitor"]
# prices = [999, 25, 75, 350]
# ```
#
# Create a dictionary called `product_catalog` where:
# - Keys are product names
# - Values are prices
#
# Print the resulting dictionary.

# %%
# Your code here:

# %% [markdown]
# ### Exercise 2.8: List of Dictionaries
# Create a list called `students` containing 3 dictionaries. Each dictionary should have:
# - "name" (string)
# - "age" (integer)
# - "major" (string)
#
# Then:
# 1. Print the name of the second student
# 2. Use a loop to print all student names
# 3. Use a loop to find the average age

# %%
# Your code here:

# %% [markdown]
# ---
#
# ## Part 3: Challenge Problems 🎯
#
# Combine everything you've learned!

# %% [markdown]
# ### Challenge 1: Movie Database
# Create a list of 4 movie dictionaries. Each should have:
# - "title": movie name
# - "year": release year
# - "rating": score out of 10
# - "watched": boolean
#
# Then:
# 1. Print titles of movies you've watched
# 2. Calculate the average rating of all movies
# 3. Find and print movies from 2020 or later
# 4. Update the "watched" status of one movie to True

# %%
# Your code here:

# %% [markdown]
# ### Challenge 2: E-commerce Analysis
# You have this shopping cart data:
# ```python
# cart = [
#     {"item": "Laptop", "price": 999, "quantity": 1, "category": "Electronics"},
#     {"item": "Mouse", "price": 25, "quantity": 2, "category": "Electronics"},
#     {"item": "Notebook", "price": 5, "quantity": 5, "category": "Stationery"},
#     {"item": "USB Cable", "price": 10, "quantity": 3, "category": "Electronics"}
# ]
# ```
#
# Calculate:
# 1. Total cost (price × quantity for each item, then sum)
# 2. Total number of items in cart
# 3. Most expensive single item
# 4. Total spent on "Electronics" category

# %%
# Your code here:

# %% [markdown]
# ### Challenge 3: Social Media Analytics
# Create a dictionary to track engagement data:
# ```python
# posts = {
#     "post1": {"likes": 150, "comments": 23, "shares": 12},
#     "post2": {"likes": 89, "comments": 15, "shares": 5},
#     "post3": {"likes": 203, "comments": 45, "shares": 28},
#     "post4": {"likes": 67, "comments": 8, "shares": 3}
# }
# ```
#
# Calculate:
# 1. Total engagement for each post (likes + comments + shares)
# 2. Which post has the highest engagement?
# 3. Average number of likes across all posts
# 4. How many posts have more than 100 likes?

# %%
# Your code here:

# %% [markdown]
# ---
#
# ## Congratulations!
#
# You've completed Week 3 practice!
#
# **What you've mastered:**
# - ✅ Reviewed all Week 1-2 concepts with practice
# - ✅ Learned dictionary basics (key-value pairs)
# - ✅ Accessed and modified dictionaries
# - ✅ Looped through dictionaries
# - ✅ Worked with lists of dictionaries
# - ✅ Combined all concepts in real-world scenarios
#
# **Keep practicing to build confidence!** 🐍
