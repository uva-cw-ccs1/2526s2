# %% [markdown]
# # Session 3: Lists
#
# **Today:** Storing multiple values in ordered collections

# %% [markdown]
# ## Lists: Ordered Collections
#
# **List** = multiple items in order
#
# Use square brackets `[ ]`

# %%
# Create lists
ages = [22, 25, 19, 31, 28]
platforms = ['Instagram', 'TikTok', 'Twitter']
print(ages)
print(platforms)

# %% [markdown]
# ## Accessing List Items
#
# ⚠️ **Python starts counting at 0!**
#
# ```
# ['Instagram', 'TikTok', 'Twitter']
#       0          1         2
# ```

# %%
platforms = ['Instagram', 'TikTok', 'Twitter']

# First item (index 0)
print(platforms[0])

# %%
# Last item (use -1)
print(platforms[-1])

# %%
# Slice: get multiple items [start:end]
print(platforms[0:2])  # Get items 0 and 1 (not 2!)

# %% [markdown]
# ## Modifying Lists

# %%
likes = [100, 150, 200]

# Add to end
likes.append(250)
print(likes)

# %%
# Change item
likes[0] = 120
print(likes)

# %%
# Useful functions
numbers = [10, 50, 30, 70, 20]
# print('Length:', len(numbers))
# print('Sum:', sum(numbers))
# print('Max:', max(numbers))

# %% [markdown]
# ## 🎯 Practice Exercise

# %%
# 1. Create list: responses = [45, 67, 23, 89, 34]

# %%
# 2. Print first and last response

# %%
# 3. Add the number 55 to responses using .append()

# %%
# 4. Change the first response to 50

# %%
# 5. Print the maximum response using max()

# %% [markdown]
# ## ✅ Key Takeaways
#
# * **Lists** `[item1, item2]` - ordered collections
# * Indexing starts at 0: `my_list[0]`
# * Negative indexing: `my_list[-1]` is last item
# * Slicing: `my_list[start:end]` gets multiple items
# * Add items: `my_list.append(item)`
# * Change items: `my_list[0] = new_value`
# * Useful functions: `len()`, `sum()`, `max()`
