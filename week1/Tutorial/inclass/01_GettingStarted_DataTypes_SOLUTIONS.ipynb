# %% [markdown]
# # Session 1: Getting Started & Data Types
#
# **Today:** Python basics, Jupyter Notebooks, and data types

# %% [markdown]
# ## What is Python?
#
# * Free programming language for data analysis
# * More flexible than SPSS
# * Used widely in research and industry

# %% [markdown]
# ## Jupyter Notebooks
#
# Two cell types:
# 1. **Code cells** - run Python code
# 2. **Markdown cells** - write notes (like this)
#
# **Run cells:** Shift + Enter

# %%
# Your first Python code - print() displays output
print('Hello, Python!')

# %% [markdown]
# ## Data Types
#
# Python has different types of data:
#
# 1. **Integers** - whole numbers: `42`
# 2. **Floats** - decimals: `3.14`
# 3. **Strings** - text (needs quotes): `'Hello'`
# 4. **Booleans** - True or False: `True`, `False`

# %%
# Integer
22

# %%
# Float
4.5

# %%
# String (text needs quotes!)
'Hello World'

# %%
# Boolean (True or False)
True

# %%
# Check type with type()
type(3.14)

# %%
# Booleans are useful for yes/no questions
is_verified = True
has_posts = False
print(is_verified, has_posts)

# %% [markdown]
# ### ⚠️ Common Error: Forgetting Quotes

# %%
# This causes an error (try it!):
# Hello World

# %%
# This works:
'Hello World'

# %% [markdown]
# ## Basic Math

# %%
# Python works like a calculator
7 + 2

# %%
10 - 4

# %%
6 * 7

# %%
20 / 4

# %% [markdown]
# ## 🎯 Practice Exercise
#
# Try these tasks:
# 1. Print your name
# 2. Calculate 127 + 456
# 3. Check the type of 3.0
# 4. Create a boolean variable for is_student = True
# 5. Create a string with a sentence

# %%
# Task 1: Print your name
print('Saurabh')

# %%
# Task 2: Calculate 127 + 456
127 + 456

# %%
# Task 3: Check type of 3.0
type(3.0)

# %%
# Task 4: Create boolean is_student = True
is_student = True
print(is_student)

# %%
# Task 5: Create a sentence
'I am learning Python for data analysis.'

# %% [markdown]
# ## ✅ Key Takeaways
#
# * Python is free and powerful for data analysis
# * Jupyter: Code cells (run code) + Markdown cells (notes)
# * Data types: **int** (whole), **float** (decimal), **str** (text with quotes), **bool** (True/False)
# * Use `print()` to display output
# * Use `type()` to check data types
#
# **Next:** Variables and operations!

# %%
```xml
<VSCode.Cell language="markdown">
# Session 1: Getting Started & Data Types

**Today:** Python basics, Jupyter Notebooks, and data types
</VSCode.Cell>
<VSCode.Cell language="markdown">
## What is Python?

* Free programming language for data analysis
* More flexible than SPSS
* Used widely in research and industry
</VSCode.Cell>
<VSCode.Cell language="markdown">
## Jupyter Notebooks

Two cell types:
1. **Code cells** - run Python code
2. **Markdown cells** - write notes (like this)

**Run cells:** Shift + Enter
</VSCode.Cell>
<VSCode.Cell language="python">
# Your first Python code - print() displays output
print('Hello, Python!')
</VSCode.Cell>
<VSCode.Cell language="markdown">
## Data Types

Python has different types of data:

1. **Integers** - whole numbers: `42`
2. **Floats** - decimals: `3.14`
3. **Strings** - text (needs quotes): `'Hello'`
4. **Booleans** - True or False: `True`, `False`
</VSCode.Cell>
<VSCode.Cell language="python">
# Integer
22
</VSCode.Cell>
<VSCode.Cell language="python">
# Float
4.5
</VSCode.Cell>
<VSCode.Cell language="python">
# String (text needs quotes!)
'Hello World'
</VSCode.Cell>
<VSCode.Cell language="python">
# Boolean (True or False)
True
</VSCode.Cell>
<VSCode.Cell language="python">
# Check type with type()
type(3.14)
</VSCode.Cell>
<VSCode.Cell language="python">
# Booleans are useful for yes/no questions
is_verified = True
has_posts = False
print(is_verified, has_posts)
</VSCode.Cell>
<VSCode.Cell language="markdown">
### ⚠️ Common Error: Forgetting Quotes
</VSCode.Cell>
<VSCode.Cell language="python">
# This causes an error (try it!):
# Hello World
</VSCode.Cell>
<VSCode.Cell language="python">
# This works:
'Hello World'
</VSCode.Cell>
<VSCode.Cell language="markdown">
## Basic Math
</VSCode.Cell>
<VSCode.Cell language="python">
# Python works like a calculator
7 + 2
</VSCode.Cell>
<VSCode.Cell language="python">
10 - 4
</VSCode.Cell>
<VSCode.Cell language="python">
6 * 7
</VSCode.Cell>
<VSCode.Cell language="python">
20 / 4
</VSCode.Cell>
<VSCode.Cell language="markdown">
## 🎯 Practice Exercise

Try these tasks:
1. Print your name
2. Calculate 127 + 456
3. Check the type of 3.0
4. Create a boolean variable for is_student = True
5. Create a string with a sentence
</VSCode.Cell>
<VSCode.Cell language="python">
# Task 1: Print your name
print('Saurabh')
</VSCode.Cell>
<VSCode.Cell language="python">
# Task 2: Calculate 127 + 456
127 + 456
</VSCode.Cell>
<VSCode.Cell language="python">
# Task 3: Check type of 3.0
type(3.0)
</VSCode.Cell>
<VSCode.Cell language="python">
# Task 4: Create boolean is_student = True
is_student = True
print(is_student)
</VSCode.Cell>
<VSCode.Cell language="python">
# Task 5: Create a sentence
'I am learning Python for data analysis.'
</VSCode.Cell>
<VSCode.Cell language="markdown">
## ✅ Key Takeaways

* Python is free and powerful for data analysis
* Jupyter: Code cells (run code) + Markdown cells (notes)
* Data types: **int** (whole), **float** (decimal), **str** (text with quotes), **bool** (True/False)
* Use `print()` to display output
* Use `type()` to check data types

**Next:** Variables and operations!
</VSCode.Cell>
```
