# %%
sample = {'Anne': ' 1098 GC', 'John': '1019 AC', 'Marthe': '1054 TG', 'Nick': '2014 AC', 'Song': '2034 EC'}

# %%
postalcode  = "2014"

# %%
print(postalcode[:2])
# Out:
# 20

# %%
#create function that classifies amsterdam if 10 and other if others

# %%
def recodepostal(postalcode):
    #print(postalcode[:2])
    if postalcode[:2] == "10":
         return 'Amsterdam'
    else:
         return 'Other'

# %%
recodepostal("1020 KL")
# Out:
# 'Amsterdam'

# %%
for key,value in sample.items():
    print(value.strip())
    print(recodepostal(value.strip()))
# Out:
# 1098 GC
# Amsterdam
# 1019 AC
# Amsterdam
# 1054 TG
# Amsterdam
# 2014 AC
# Other
# 2034 EC
# Other

# %%
poepleams = {}

# %%
poepleams
